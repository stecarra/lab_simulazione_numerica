# %% [markdown]
# # <span style="color:green"> Numerical Simulation Laboratory (NSL) </span>
# ## <span style="color:blue">  Numerical exercises 2</span>

# %% [markdown]
# ### Exercise 02.1
# - Compute the following 1D integral via Monte Carlo
# $$I = \int_0^1 \frac{\pi}{2}\cos(\pi x/2) dx = 1$$

# %% [markdown]
# 1. sampling a uniform distribution in $[0,1]$
# 2. using importance sampling (i.e. sampling a non-uniform probability in $[0,1]$)
#
# <span style="color:red">Show a picture of both your estimations of $I$</span> and their uncertainties with a large number of *throws* $M$ (e.g. $M\ge 10^4$) as a function of the number of blocks, $N$</font>.

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import math

# %%
#integrale usando distribuzione uniforme
n, I, err, I_imp, err_imp = np.loadtxt("integral_uni.out", usecols=(0,1,2,3,4), delimiter= "\t", unpack='true')
plt.errorbar(n, I, yerr=err)
plt.xlabel('number of blocks')
plt.ylabel('integral')
plt.show()

# %%
plt.errorbar(n, I_imp, yerr=err_imp)
plt.xlabel('number of blocks')
plt.ylabel('integral by importance sampling')
plt.show()

# %% [markdown]
# As we can infer from the two graphs above, the integral calculation by importance sampling is faster than the one uniformly sampled one. In fact, with the same amount of steps, we get smaller variance values.

# %% [markdown]
# ### Exercise 02.2
# - <span style="color:red">3D Random Walks (RW) on a cubic lattice and in the continuum:</span> Repeat many times (e.g. say $10^4$) the simulation of a random walk in 3D always starting at the origin

# %% [markdown]
# 1. on a cubic lattice with lattice constant $a=1$; at each discrete time the walker makes a forward or backward step of length equal to $a$ in one of the 3 principal directions of the lattice: $x$, $y$ or $z$
# 2. in the continuum; at each discrete time the walker makes a step of length equal to $a(=1)$ along a **random direction** obtained by sampling **uniformly** the solid angle: $\theta \in [0,\pi]$ and $\phi \in [0,2\pi]$
#
# <span style="color:red">Show a picture of $\sqrt{\langle |\vec{r}_N|^2 \rangle_{RW}}$ for both RWs</span>, with their statistical uncertainties, as function of the step $i\in [0,10^2]$.
#
# Suggestion: divide your $M$ throws into a reasonable number of blocks, compute $\sqrt{\langle |\vec{r}_N|^2 \rangle_{RW}}$ as function of the step $i\in [0,10^2]$ in each block and use these values (for fixed $i$) to obtain the average value and its statistical uncertainty.
#
# Note that you could try to fit both results with a function like $f(N)=k\sqrt{N}$. Do your results indicate a diffusive behavior?

# %%
n, RW, err, RW_con, err_con = np.loadtxt("RW.out", usecols=(0,1,2,3,4), delimiter= "\t", unpack='true')
plt.errorbar(n, RW, yerr=err)
plt.xlabel('number of steps')
plt.ylabel('distance')
plt.title('RW on a lattice')
plt.show()

# %%
plt.errorbar(n, RW_con, yerr=err_con)
plt.xlabel('number of steps')
plt.ylabel('distance')
plt.title('continuos RW')
plt.show()

# non so se gli errori sono giusti mi sembrano piccoli
# forse ho sbagliato a scrivere le formule 
# per la dev std ??? penso di aver usato le solito però...

# %% [markdown]
# Both the discrete and continuum cases show a good compatibility with the model function $f(s) = k \sqrt s$, where k is some constant. This suggests that these RW walk, if performed for a large number of times, show a diffusive behaviour, and thus the coefficient k is $k= \sqrt{2D} $ where D is the diffusive coefficient.
